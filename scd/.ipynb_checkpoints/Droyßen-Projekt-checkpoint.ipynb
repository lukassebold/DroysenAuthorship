# %% [markdown]
# # Droyßen Authorship-Attribution

# %% [markdown]
# ## Importe

# %%
import os

import sklearn.feature_extraction.text as text
import sklearn.preprocessing as preprocessing

import sklearn.model_selection as model_selection
import sklearn.metrics as metrics

import scipy.spatial.distance as scidist
import sklearn.decomposition
import scipy.cluster.hierarchy as hierarchy

import matplotlib.pyplot as plt
import numpy as np

from collections import Counter
import re

# %matplotlib inline

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Helferfunktion zum Laden der Daten

# %%
def load_directory(directory, max_length):
    documents, authors, titles = [], [], [] 
    for filename in os.scandir(directory):
        if not filename.name.endswith('.txt'):
            continue
        author, _ = os.path.splitext(filename.name)

        with open(filename.path, encoding = "UTF-8") as f:
            contents = f.read()
        lemmas = contents.lower().split()
        start_idx, end_idx, segm_cnt = 0, max_length, 1

        # extract slices from the text:
        while end_idx < len(lemmas):
            documents.append(' '.join(lemmas[start_idx:end_idx]))
            authors.append(author[0])
            title = filename.name.replace('.txt', '').split('_')[1]
            titles.append(f"{title}-{segm_cnt}")

            start_idx += max_length
            end_idx += max_length
            segm_cnt += 1

    return documents, authors, titles

# %% [markdown]
# Vokabular: verschiedene Listen: Ausgangspunkt: most frequent words, dann schrittweise neue Listen erstellen mit Wörtern, die man rausnimmt (mit Begründung im Text), dann über Code von Ursprungsliste "abziehen"
# Anders als Kestemon: dort war die Liste mit "##" aussortiert

# %% [markdown]
# ## Laden der Daten

# %%
documents, authors, titles = load_directory('../data/texts', 3000)

# %%
print(f"Anzahl der Dokumente: {len(documents)}")
print(authors[:20])
print(titles)
# Out:
# Anzahl der Dokumente: 76
# ['d', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd']
# ['alexander1833-1', 'alexander1833-2', 'alexander1833-3', 'alexander1833-4', 'alexander1833-5', 'alexander1833-6', 'alexander1833-7', 'alexander1833-8', 'alexander1833-9', 'alexander1833-10', 'alexander1833-11', 'alexander1833-12', 'alexander1833-13', 'alexander1833-14', 'alexander1833-15', 'alexander1833-16', 'alexander1833-17', 'alexander1833-18', 'alexander1833-19', 'alexander1833-20', 'alexander1833-21', 'alexander1833-22', 'alexander1833-23', 'alexander1833-24', 'alexander1833-25', 'alexander1833-26', 'alexander1833-27', 'alexander1833-28', 'alexander1833-29', 'alexander1833-30', 'alexander1833-31', 'alexander1833-32', 'alexander1833-33', 'alexander1833-34', 'alexander1833-35', 'alexander1833-36', 'alexander1833-37', 'alexander1833-38', 'alexander1833-39', 'alexander1833-40', 'alexander1833-41', 'alexander1833-42', 'alexander1833-43', 'alexander1833-44', 'alexander1833-45', 'alexander1833-46', 'alexander1833-47', 'alexander1833-48', 'alexander1833-49', 'alexander1833-50', 'alexander1833-51', 'alexander1833-52', 'alexander1833-53', 'alexander1833-54', 'alexander1833-55', 'alexander1833-56', 'alexander1833-57', 'alexander1833-58', 'alexander1833-59', 'alexander1833-60', 'alexander1833-61', 'alexander1833-62', 'alexander1833-63', 'alexander1833-64', 'alexander1833-65', 'alexander1833-66', 'alexander1833-67', 'historik1868-1', 'historik1868-2', 'historik1868-3', 'historik1868-4', 'historik1868-5', 'historik1868-6', 'historik1868-7', 'historik1868-8', 'krisis1854-1']

# %% [markdown]
# ## Erstellen der Worldist

# %%
# Creating word frequencies with counter

textjoins = " ".join(documents)


wordcounts =  Counter(re.findall('\w+', textjoins))

mostfrequent = wordcounts.most_common(100)
vocab = []

for item in mostfrequent:
    vocab.append(item[0])
print(vocab)
# Out:
# ['die', 'der', 'und', 'zu', 'den', 'in', 'des', 'von', 'das', 'dem', 'mit', 'er', 'ſich', 'auf', 'ſie', 'nicht', 'war', 'an', 'nach', 'daß', 'es', 'alexander', 'als', 'ſo', 'durch', 'ein', 'um', 'aus', 'im', 'fu', 'wie', 'hatte', 'eine', 'ko', 'u', 'ſein', 'zum', 'man', 'unter', 'noch', 'gegen', 'bei', 'aber', 'iſt', 'ſeine', 'ihm', 'nur', 'oder', 'waren', 'da', 'ſelbſt', 'ſeiner', 'auch', 'vor', 'für', 'ihn', 'stadt', 'zur', 'ſei', 'so', 'wenn', 'dieſe', 'wurde', 'ge', 'ihre', 'p', 'ist', 'am', 'zeit', 'sie', 'gen', 'bis', 'über', 'einen', 'ber', 'r', 'alexanders', 'einer', 'dieſer', 'hat', 'sich', 'mehr', 'werden', 'arrian', 'was', 'ohne', 'dann', 'ihrer', 'hatten', 'ſchon', 'haben', 'einem', 'könig', 'ihr', 'ſeinen', 'jetzt', 'ihnen', 'nig', 'habe', 'macedonier']

# %% [markdown]
# ## Erstelle Vokabular

# %%
#vocab = [l.strip() for l in open('data/wordlist.txt') if not l.startswith('#') and l.strip()][:65]

# %%
# Instantiieren
vectorizer = text.CountVectorizer(token_pattern=r"(?u)\b\w+\b", vocabulary=vocab)

# Fit und Transform
v_documents = vectorizer.fit_transform(documents).toarray()

# Check
print(v_documents.shape)
print(vectorizer.get_feature_names_out()[:5])
# Out:
# (76, 100)
# ['die' 'der' 'und' 'zu' 'den']

# %%
# Normalisiere
n_v_documents = preprocessing.normalize(v_documents.astype(float), norm='l1')

# Check
print(n_v_documents.shape)
# Out:
# (76, 100)

# %%
# Z-Transformation
scaler = preprocessing.StandardScaler()
s_documents = scaler.fit_transform(n_v_documents)

# %% [markdown]
# ## Helferfunktion für Plotten

# %%
def plot_z_scores(nchunk=0):

    fig, ax = plt.subplots(figsize=(10,6))

    labels = vectorizer.get_feature_names_out()
    x = np.arange(0,100)

    ax.bar(x=x, height=s_documents[nchunk])
    ax.set_xticks(x)
    ax.set_xticklabels(labels, rotation=90, fontsize=12)
    ax.set_title(f'Textchunk {authors[nchunk]}_{titles[nchunk]}')
    ax.set_xlabel('Features', fontsize=14)
    ax.set_ylabel('z-Werte', fontsize=14)
    ax.set_ylim(-3.5, 3.5)
    ax.yaxis.grid();

# %%
# Beispielplot für ersten Chunk, als Test
plot_z_scores(nchunk=0)

# %% [markdown]
# ## Cityblock-Distanzen zu allen Chunks

# %%
test_doc = s_documents[0]

distances = [ scidist.cityblock(test_doc, train_doc) for train_doc in s_documents[1:] ]

# %%
for distance, author, title in zip(distances, authors[1:], titles[1:]):
    print(f'{distance} => {author}_{title}')
# Out:
# 89.36055929818143 => d_alexander1833-2
# 99.29766927784674 => d_alexander1833-3
# 100.40312602040062 => d_alexander1833-4
# 91.54504671669417 => d_alexander1833-5
# 109.57328356305915 => d_alexander1833-6
# 111.1321470353265 => d_alexander1833-7
# 104.79514085932142 => d_alexander1833-8
# 99.59415807606571 => d_alexander1833-9
# 105.09308835478502 => d_alexander1833-10
# 105.84371648429597 => d_alexander1833-11
# 112.43598136713554 => d_alexander1833-12
# 101.8480288825051 => d_alexander1833-13
# 115.94275760091698 => d_alexander1833-14
# 113.28138412238984 => d_alexander1833-15
# 106.4869403695544 => d_alexander1833-16
# 105.3956896740783 => d_alexander1833-17
# 97.6021098540458 => d_alexander1833-18
# 100.92734188119894 => d_alexander1833-19
# 103.29068544386993 => d_alexander1833-20
# 102.61580016645739 => d_alexander1833-21
# 112.60817829437796 => d_alexander1833-22
# 106.26950973440024 => d_alexander1833-23
# 96.31446102920614 => d_alexander1833-24
# 98.4766812483363 => d_alexander1833-25
# 105.18711236026937 => d_alexander1833-26
# 100.96833281391852 => d_alexander1833-27
# 94.06769754364848 => d_alexander1833-28
# 95.10574152573078 => d_alexander1833-29
# 108.08152980615941 => d_alexander1833-30
# 109.75293369310015 => d_alexander1833-31
# 110.67311622573403 => d_alexander1833-32
# 101.83063502414612 => d_alexander1833-33
# 100.0704821527699 => d_alexander1833-34
# 118.53780726351093 => d_alexander1833-35
# 115.54325352445136 => d_alexander1833-36
# 109.56785214263608 => d_alexander1833-37
# 116.95939583608894 => d_alexander1833-38
# 110.64738931658306 => d_alexander1833-39
# 126.78376652412592 => d_alexander1833-40
# 120.59555779424988 => d_alexander1833-41
# 111.18316412733226 => d_alexander1833-42
# 112.32140608927966 => d_alexander1833-43
# 103.00924394489708 => d_alexander1833-44
# 108.74534297703414 => d_alexander1833-45
# 111.56800885690954 => d_alexander1833-46
# 105.54458176373441 => d_alexander1833-47
# 104.22140591136777 => d_alexander1833-48
# 109.62861250525197 => d_alexander1833-49
# 111.54859450399537 => d_alexander1833-50
# 111.80776036619658 => d_alexander1833-51
# 111.6487035379365 => d_alexander1833-52
# 103.90393570186025 => d_alexander1833-53
# 98.82680809315573 => d_alexander1833-54
# 100.8047692068512 => d_alexander1833-55
# 105.37089811938252 => d_alexander1833-56
# 120.90885559899326 => d_alexander1833-57
# 114.97918275029231 => d_alexander1833-58
# 123.50170863861267 => d_alexander1833-59
# 123.01303303197578 => d_alexander1833-60
# 116.53241610080957 => d_alexander1833-61
# 105.40061560463185 => d_alexander1833-62
# 122.4032675155409 => d_alexander1833-63
# 103.76149767116588 => d_alexander1833-64
# 105.32179905053911 => d_alexander1833-65
# 116.54562232860887 => d_alexander1833-66
# 105.55061144634425 => d_alexander1833-67
# 134.45846663372507 => d_historik1868-1
# 131.81649671846938 => d_historik1868-2
# 140.96960543698754 => d_historik1868-3
# 131.0587451624245 => d_historik1868-4
# 132.00420715600154 => d_historik1868-5
# 138.6949088318176 => d_historik1868-6
# 149.8079548370537 => d_historik1868-7
# 131.65616784275778 => d_historik1868-8
# 140.75436090015256 => d_krisis1854-1

# %%
print(f'geringste Cityblock-Distanz: {distances[np.argmin(distances)]} => {authors[np.argmin(distances) + 1]}_{titles[np.argmin(distances) + 1]}')
# Out:
# geringste Cityblock-Distanz: 89.36055929818143 => d_alexander1833-2

# %% [markdown]
# ### Plotte Testchunk und die jeweils nächsten und entferntesten Chunks

# %%
plot_z_scores(nchunk=0)                         # Testchunk
plot_z_scores(nchunk=np.argmin(distances) + 1)  # nächster Chunk
plot_z_scores(nchunk=np.argmax(distances) + 1)  # entfernster Chunk

# %% [markdown]
# ## Delta-Objekt erstellen

# %%
class Delta:
    """Delta-Based Authorship Attributer."""

    def fit(self, X, y):
        """Fit (or train) the attributer.

        Arguments:
            X: a two-dimensional array of size NxV, where N represents
               the number of training documents, and V represents the
               number of features used.
            y: a list (or NumPy array) consisting of the observed author
                for each document in X.

        Returns:
            Delta: A trained (fitted) instance of Delta.

        """
        self.train_y = np.array(y)
        self.scaler = preprocessing.StandardScaler(with_mean=False)
        self.train_X = self.scaler.fit_transform(X)

        return self

    def predict(self, X, metric='cityblock'):
        """Predict the authorship for each document in X.

        Arguments:
            X: a two-dimensional (sparse) matrix of size NxV, where N
               represents the number of test documents, and V represents
               the number of features used during the fitting stage of
               the attributer.
            metric (str, optional): the metric used for computing
               distances between documents. Defaults to 'cityblock'.

        Returns:
            ndarray: the predicted author for each document in X.

        """
        X = self.scaler.transform(X)
        dists = scidist.cdist(X, self.train_X, metric=metric)
        return self.train_y[np.argmin(dists, axis=1)]

# %% [markdown]
# ## Train-Test Split

# %%
test_size = len(set(authors)) * 2

(train_documents, test_documents, train_authors, test_authors) = model_selection.train_test_split(n_v_documents,  # normalisierte Daten werden genutzt
                                                                                                 authors, 
                                                                                                 test_size=test_size, 
                                                                                                 stratify=authors, 
                                                                                                 random_state=42)
                                                                                                 
print(f'N={test_documents.shape[0]} Test Dokumente mit '
      f'V={test_documents.shape[1]} Features.')

print(f'N={train_documents.shape[0]} Training Dokumente mit '
      f'V={train_documents.shape[1]} Features.')
# Out:
# N=2 Test Dokumente mit V=100 Features.
# N=74 Training Dokumente mit V=100 Features.

# %% [markdown]
# ## Evaluation

# %%
delta = Delta()                             # Delta Classifier wird instantiiert
delta.fit(train_documents, train_authors)   # Delta Classifier wird gefitted
preds = delta.predict(test_documents)       # Delta Classifier klassifziert Test Dokumente

# Ausgabe
for true, pred in zip(test_authors, preds):
    _connector = 'ABER' if true != pred else 'und'
    print(f'Der Autor ist {true} {_connector} {pred} wurde vorhergesagt.')

accuracy = metrics.accuracy_score(preds, test_authors)
print(f'\nAccuracy der Vorhersagen: {accuracy:.1f}')
# Out:
# Der Autor ist d und d wurde vorhergesagt.
# Der Autor ist d und d wurde vorhergesagt.
#
# Accuracy der Vorhersagen: 1.0

# %% [markdown]
# # Anwendung

# %%
# Einlesen der Trainingsdaten
train_documents, train_authors, train_titles = load_directory('../data/texts/Testtext', 3301)

vectorizer = text.CountVectorizer(token_pattern=r"(?u)\b\w+\b", vocabulary=vocab)
                                  
v_train_documents = vectorizer.fit_transform(train_documents).toarray()
v_train_documents = preprocessing.normalize(v_train_documents.astype(float), norm='l1')

delta = Delta().fit(v_train_documents, train_authors)

# %%
# Einlesen der Testdaten
test_docs, test_authors, test_titles = load_directory('../data/texts/Testtext', 3301)

v_test_docs = vectorizer.transform(test_docs).toarray()
v_test_docs = preprocessing.normalize(v_test_docs.astype(float), norm='l1')

# %% [markdown]
# ## Klassifizieren mit Cityblock-Distanz

# %%
predictions = delta.predict(v_test_docs)

for test_author, test_title, prediction in zip(test_authors, test_titles, predictions):
    print(f'Quelle: {test_author}_{test_title} => klassifiziert als {prediction}')
# Out:
# Quelle: T_inq-1 => klassifiziert als T
